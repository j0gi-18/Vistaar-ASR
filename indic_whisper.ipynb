# %% [markdown]
# <a href="https://colab.research.google.com/github/j0gi-18/Vistaar-ASR/blob/main/indic_whisper.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Testing Whisper hindi on Kathbath dataset

# %%
# !git clone https://github.com/AI4Bharat/vistaar.git

# %%
# install ffmpeg and requirements.txt from the repository documentation
# !sudo apt install ffmpeg
# !pip install -r /content/vistaar/requirements.txt
# Out:
# Reading package lists... Done
# Building dependency tree... Done
# Reading state information... Done
# ffmpeg is already the newest version (7:4.4.2-0ubuntu0.22.04.1).
# 0 upgraded, 0 newly installed, 0 to remove and 45 not upgraded.
# ...
#   Cloning https://github.com/yt-dlp/yt-dlp.git to /tmp/pip-req-build-plqwainx
#   Running command git clone --filter=blob:none --quiet https://github.com/yt-dlp/yt-dlp.git /tmp/pip-req-build-plqwainx
#   Resolved https://github.com/yt-dlp/yt-dlp.git to commit 89f535e2656964b4061c25a7739d4d6ba0a30568
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
# ...
#   Cloning https://github.com/huggingface/transformers to /tmp/pip-req-build-awu84hig
#   Running command git clone --filter=blob:none --quiet https://github.com/huggingface/transformers /tmp/pip-req-build-awu84hig
# ...

# %%
# %cd /content/vistaar
# Out:
# /content/vistaar

# %%
# download kathbath datset
# !wget https://objectstore.e2enetworks.net/indic-asr-public/indicwhisper/vistaar_benchmarks/kathbath.zip
# Out:
# --2024-04-25 17:58:42--  https://objectstore.e2enetworks.net/indic-asr-public/indicwhisper/vistaar_benchmarks/kathbath.zip
# Resolving objectstore.e2enetworks.net (objectstore.e2enetworks.net)... 164.52.210.57, 164.52.210.96, 101.53.136.19, ...
# Connecting to objectstore.e2enetworks.net (objectstore.e2enetworks.net)|164.52.210.57|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 3457654951 (3.2G) [application/zip]
# Saving to: ‘kathbath.zip’
#
# kathbath.zip        100%[===================>]   3.22G  34.7MB/s    in 88s
#
# 2024-04-25 18:00:10 (37.5 MB/s) - ‘kathbath.zip’ saved [3457654951/3457654951]

# %%
# download whisper hindi model
# !wget https://objectstore.e2enetworks.net/indic-asr-public/indicwhisper/all_lang_models/hindi_models.zip
# Out:
# --2024-04-25 18:00:10--  https://objectstore.e2enetworks.net/indic-asr-public/indicwhisper/all_lang_models/hindi_models.zip
# Resolving objectstore.e2enetworks.net (objectstore.e2enetworks.net)... 164.52.210.57, 101.53.136.19, 101.53.136.18, ...
# Connecting to objectstore.e2enetworks.net (objectstore.e2enetworks.net)|164.52.210.57|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 4262614425 (4.0G) [application/zip]
# Saving to: ‘hindi_models.zip’
#
# hindi_models.zip    100%[===================>]   3.97G  45.4MB/s    in 93s
#
# 2024-04-25 18:01:45 (43.8 MB/s) - ‘hindi_models.zip’ saved [4262614425/4262614425]

# %%
# download Gramvaani dataset
# !wget  https://asr.iitm.ac.in/Gramvaani/NEW/GV_Eval_3h.tar.gz
# Out:
# --2024-04-25 18:01:45--  https://asr.iitm.ac.in/Gramvaani/NEW/GV_Eval_3h.tar.gz
# Resolving asr.iitm.ac.in (asr.iitm.ac.in)... 103.158.43.117
# Connecting to asr.iitm.ac.in (asr.iitm.ac.in)|103.158.43.117|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 62063203 (59M) [application/x-gzip]
# Saving to: ‘GV_Eval_3h.tar.gz’
#
# GV_Eval_3h.tar.gz   100%[===================>]  59.19M  60.3MB/s    in 1.0s
#
# 2024-04-25 18:01:46 (60.3 MB/s) - ‘GV_Eval_3h.tar.gz’ saved [62063203/62063203]

# %%
# !unzip kathbath.zip
# Out:
# Streaming output truncated to the last 5000 lines.
#   inflating: kathbath/tamil/wavs/844424930425733-685-f.wav
#   inflating: kathbath/tamil/wavs/844424930592589-47-f.wav
#   inflating: kathbath/tamil/wavs/844424930452982-1009-f.wav
#   inflating: kathbath/tamil/wavs/844424930705398-709-f.wav
#   inflating: kathbath/tamil/wavs/844424930743365-877-f.wav
#   inflating: kathbath/tamil/wavs/844424933409713-128-m.wav
#   inflating: kathbath/tamil/wavs/844424933243254-109-m.wav
#   inflating: kathbath/tamil/wavs/844424933226027-311-m.wav
#   inflating: kathbath/tamil/wavs/844424930743306-877-f.wav
#   inflating: kathbath/tamil/wavs/844424933409678-128-m.wav
#   inflating: kathbath/tamil/wavs/844424930453006-1009-f.wav
#   inflating: kathbath/tamil/wavs/844424930669837-685-f.wav
#   inflating: kathbath/tamil/wavs/844424933236932-311-m.wav
#   inflating: kathbath/tamil/wavs/844424930743301-877-f.wav
#   inflating: kathbath/tamil/wavs/844424933263926-1074-m.wav
# ...

# %%
# !unzip hindi_models.zip
# Out:
# Archive:  hindi_models.zip
#    creating: hindi_models/
#    creating: hindi_models/whisper-large-hi-noldcil/
#   inflating: hindi_models/whisper-large-hi-noldcil/tokenizer_config.json
#   inflating: hindi_models/whisper-large-hi-noldcil/merges.txt
#   inflating: hindi_models/whisper-large-hi-noldcil/rng_state_1.pth
#   inflating: hindi_models/whisper-large-hi-noldcil/rng_state_0.pth
#   inflating: hindi_models/whisper-large-hi-noldcil/vocab.json
#   inflating: hindi_models/whisper-large-hi-noldcil/added_tokens.json
#   inflating: hindi_models/whisper-large-hi-noldcil/training_args.bin
#  extracting: hindi_models/whisper-large-hi-noldcil/latest
#   inflating: hindi_models/whisper-large-hi-noldcil/zero_to_fp32.py
#   inflating: hindi_models/whisper-large-hi-noldcil/rng_state_2.pth
#   inflating: hindi_models/whisper-large-hi-noldcil/trainer_state.json
#   inflating: hindi_models/whisper-large-hi-noldcil/rng_state_3.pth
# ...

# %%
# !tar -xf GV_Eval_3h.tar.gz

# %%
# !pwd
# Out:
# /content/vistaar

# %%
# !ls
# Out:
# evaluation.py  GV_Eval_3h.tar.gz  hindi_models.zip  kathbath.zip  README.md	    training.py
# GV_Eval_3h     hindi_models	  kathbath	    LICENSE	  requirements.txt  transcribe.py

# %% [markdown]
# # **WER: 0.10421276219134437 and CER: 0.03768600388182014**

# %%
# evaluation script
# command line code for testing the model on kathbath dataset
# arguments are 1.Model_path 2.Manifest_path 3.Manifest_name 4.device(gpu or cpu(-1) ) 5.batch_size 6.language_key
# batch size kept 1 to bypass the error where model detectes multiple languages(fails to recognise all given text is hindi) in same batch

# !python evaluation.py --model_path "/content/vistaar/hindi_models/whisper-medium-hi_alldata_multigpu" \
--manifest_path "/content/vistaar/kathbath/hindi/manifest.json" \
--manifest_name "manifest.json" \
--device 0 \
--batch_size 1 \
--language 'hi'
# Out:
# 2024-04-25 18:04:00.952812: E external/local_xla/xla/stream_executor/cuda/cuda_dnn.cc:9261] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# 2024-04-25 18:04:00.952867: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:607] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# 2024-04-25 18:04:01.069697: E external/local_xla/xla/stream_executor/cuda/cuda_blas.cc:1515] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# 2024-04-25 18:04:01.299314: I tensorflow/core/platform/cpu_feature_guard.cc:182] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 AVX512F FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# ...
